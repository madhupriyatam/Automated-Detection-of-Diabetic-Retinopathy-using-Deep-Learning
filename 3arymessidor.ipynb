# %%
pwd
# Out:
# u'/content/drive/My Drive/FirstAid-master'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
cd FirstAid-master/
# Out:
# /content/drive/My Drive/FirstAid-master

# %%
 # !python train_CNNclassification.py --pTrain='../Messidordataset/preprocessed/3aryh5/train' --pVal='../Messidordataset/preprocessed/3aryh5/validation' --pTest='../Messidordataset/preprocessed/3aryh5/test' --pModel='../Messidordataset/3ary_model/Alex' --pLog='../Messidordataset/logs/alex_3ary.txt'--name='alex_3ary' --net='Alex' --nClass='3' --pVis='../Messidordataset/3ary_model/Alex'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1111 09:47:18.244733 140122759776128 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:112: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("Placeholder_2:0", shape=(12, 256, 256, 3), dtype=float32)
# Before
# W1111 09:47:18.247878 140122759776128 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:118: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# [11, 11]
# [1, 256, 256, 3]
# W1111 09:47:18.250643 140122759776128 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/layers.py:66: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
 # !python train_CNNclassification.py --pTrain='../Messidordataset/preprocessed/3aryh5/train' --pVal='../Messidordataset/preprocessed/3aryh5/validation' --pTest='../Messidordataset/preprocessed/3aryh5/test' --pModel='../Messidordataset/3ary_model/vgg19' --pLog='../Messidordataset/logs/vgg19_3ary.txt'--name='vgg19' --net='VGG19' --nClass='3' --pVis='../Messidordataset/3ary_model/vgg19'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1111 17:54:24.577440 139979454048128 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:112: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("Placeholder_2:0", shape=(12, 256, 256, 3), dtype=float32)
# Before
# W1111 17:54:24.595118 139979454048128 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:118: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# [3, 3]
# [1, 256, 256, 3]
# W1111 17:54:24.598012 139979454048128 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/layers.py:66: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
 # !python train_CNNclassification.py --pTrain='../Messidordataset/preprocessed/4aryh5/train' --pVal='../Messidordataset/preprocessed/4aryh5/validation' --pTest='../Messidordataset/preprocessed/4aryh5/test' --pModel='../Messidordataset/4ary_model/Alex4ary' --pLog='../Messidordataset/logs/alex_4ary.txt'--name='Alex4ary' --net='Alex' --nClass='4' --pVis='../Messidordataset/4ary_model/Alex4ary'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1115 04:21:47.836420 139743550384000 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:112: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("Placeholder_2:0", shape=(12, 256, 256, 3), dtype=float32)
# Before
# W1115 04:21:47.855335 139743550384000 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:118: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# [11, 11]
# [1, 256, 256, 3]
# W1115 04:21:47.858211 139743550384000 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/layers.py:66: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
 # !python train_CNNclassification.py --pTrain='../Messidordataset/preprocessed/4aryh5/train' --pVal='../Messidordataset/preprocessed/4aryh5/validation' --pTest='../Messidordataset/preprocessed/4aryh5/test' --pModel='../Messidordataset/4ary_model/Google4ary' --pLog='../Messidordataset/logs/Google_4ary.txt'--name='Google4ary' --net='GoogLe' --nClass='4' --pVis='../Messidordataset/4ary_model/Google4ary'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1115 06:36:15.117214 139840085243776 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:112: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("Placeholder_2:0", shape=(12, 256, 256, 3), dtype=float32)
# Before
# W1115 06:36:15.121059 139840085243776 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:118: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# [7, 7]
# [1, 256, 256, 3]
# W1115 06:36:15.124154 139840085243776 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/layers.py:66: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
 # !python train_CNNclassification.py --pTrain='../Messidordataset/preprocessed/4aryh5/train' --pVal='../Messidordataset/preprocessed/4aryh5/validation' --pTest='../Messidordataset/preprocessed/4aryh5/test' --pModel='../Messidordataset/4ary_model/VGG19-4ary' --pLog='../Messidordataset/logs/VGG19-4ary.txt'--name='VGG19-4ary' --net='VGG19' --nClass='4' --pVis='../Messidordataset/4ary_model/VGG19-4ary'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1119 22:45:38.936131 140219979282304 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:112: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("Placeholder_2:0", shape=(12, 256, 256, 3), dtype=float32)
# Before
# W1119 22:45:38.950041 140219979282304 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:118: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# [3, 3]
# [1, 256, 256, 3]
# W1119 22:45:38.953067 140219979282304 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/layers.py:66: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
# !python --version
# Out:
# Python 2.7.15+
