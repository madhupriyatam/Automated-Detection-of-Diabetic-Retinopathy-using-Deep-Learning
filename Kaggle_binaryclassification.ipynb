# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive/Kaggledataset
# Out:
# /content/drive/My Drive/Kaggledataset

# %%
cd ..
# Out:
# /content/drive/My Drive

# %%
cd FirstAid-master/
# Out:
# /content/drive/My Drive/FirstAid-master

# %%
cd FirstAid-master/
# Out:
# /content/drive/My Drive/FirstAid-master

# %%
 # !python train_CNNclassification.py --pTrain='../Kaggledataset/preprocessed/binaryh5/train' --pVal='../Kaggledataset/preprocessed/binaryh5/validation' --pTest='../Kaggledataset/preprocessed/binaryh5/test' --pModel='../Kaggledataset/models/Googlenet/binary' --pLog='../Kaggledataset/models/Googlenet/binary/log.txt' --name='google-b' --net='GoogLe' --pVis='../Kaggledataset/models/Googlenet/binary' --nGPU='4'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1121 20:49:15.925281 139871205226368 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:112: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("Placeholder_2:0", shape=(12, 256, 256, 3), dtype=float32)
# Before
# W1121 20:49:15.930054 139871205226368 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/classification.py:118: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# [7, 7]
# [1, 256, 256, 3]
# W1121 20:49:15.933408 139871205226368 module_wrapper.py:139] From /content/drive/My Drive/FirstAid-master/utils/layers.py:66: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
pwd
# Out:
# u'/content/drive/My Drive/FirstAid-master'

# %%
cd drive/My\ Drive/Kaggledataset
# Out:
# /content/drive/My Drive/Kaggledataset

# %%
cd ..
# Out:
# /content/drive/My Drive

# %%
cd FirstAid-master/
# Out:
# /content/drive/My Drive/FirstAid-master

# %%
pwd
# Out:
# u'/content/drive/My Drive/FirstAid-master'

# %%
cd Kaggledataset/preprocessed/binaryh5/
# Out:
# /content/drive/My Drive/Kaggledataset/preprocessed/binaryh5

# %%
ls -l *
